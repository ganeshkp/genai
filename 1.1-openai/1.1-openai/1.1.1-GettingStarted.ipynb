# %% [markdown]
# #### Getting started With Langchain And Open AI
#
# In this quickstart we'll see how to:
#
# - Get setup with LangChain, LangSmith and LangServe
# - Use the most basic and common components of LangChain: prompt templates, models, and output parsers.
# - Build a simple application with LangChain
# - Trace your application with LangSmith
# - Serve your application with LangServe

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['OPENAI_API_KEY']=os.getenv("OPENAI_API_KEY")
## Langsmith Tracking
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(model="gpt-4o")
print(llm)
# Out:
# client=<openai.resources.chat.completions.completions.Completions object at 0x7f307bfd7fe0> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x7f307bffa4b0> root_client=<openai.OpenAI object at 0x7f3084cae1e0> root_async_client=<openai.AsyncOpenAI object at 0x7f3084bd6930> model_name='gpt-4o' model_kwargs={} openai_api_key=SecretStr('**********')

# %%
## Input and get response form LLM

result=llm.invoke("What is generative AI?")

# %%
print(result)
# Out:
# content='Generative AI refers to a class of artificial intelligence systems designed to generate new content. These systems are capable of producing text, images, music, or other media forms that are often indistinguishable from what a human might create. Generative AI models are typically based on machine learning techniques, especially deep learning, where they learn patterns and structures from existing data and use this knowledge to generate new, similar instances.\n\nSome key techniques used in generative AI include:\n\n1. **Generative Adversarial Networks (GANs):** These consist of two neural networks, a generator and a discriminator, that are trained simultaneously. The generator creates new data instances, while the discriminator evaluates them. The goal is for the generator to produce data that the discriminator cannot distinguish from real data.\n\n2. **Variational Autoencoders (VAEs):** These are models that learn to encode input data into a latent space and then decode from this space to reconstruct the input data. They are often used for generating new data instances by sampling from the latent space.\n\n3. **Transformer-based Models:** Models like GPT (Generative Pre-trained Transformer) use transformers to understand and generate human-like language. These models have been very successful in generating text, translating language, and even creating conversational agents.\n\nGenerative AI has applications in diverse fields, including:\n\n- **Content Creation:** Automating the creation of articles, marketing materials, and other textual content.\n- **Art and Design:** Producing new artworks or design concepts.\n- **Entertainment:** Generating music, design elements for video games, and movie scripts.\n- **Healthcare:** Creating synthetic medical data for research and training purposes.\n- **Finance:** Simulating stock data for financial modeling and risk analysis.\n\nGenerative AI is a rapidly growing field with significant potential to transform how we create and interact with digital content.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 370, 'prompt_tokens': 13, 'total_tokens': 383, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_90d33c15d4', 'id': 'chatcmpl-BCuf2hTqEdHjMKmApelYI5WAQvTmz', 'finish_reason': 'stop', 'logprobs': None} id='run-f6761f5c-17c0-4d28-8122-52e444a5ce63-0' usage_metadata={'input_tokens': 13, 'output_tokens': 370, 'total_tokens': 383, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
### Chatprompt Template
from langchain_core.prompts import ChatPromptTemplate

prompt=ChatPromptTemplate.from_messages(
    [
        ("system","You are an expert AI Engineer. Provide me answers based on the questions"),
        ("user","{input}")
    ]

)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer. Provide me answers based on the questions'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
## chain 
chain=prompt|llm

response=chain.invoke({"input":"what is langsmith and Can you tell me about Langsmith?"})
print(response)
# Out:
# content="Langsmith is a toolset developed by Langchain that assists developers in debugging and testing applications that integrate language models. This functionality is essential for refining and optimizing how applications interact with language processing models, ensuring they perform reliably and accurately. Langsmith offers a variety of features, including:\n\n1. **Trace Reports**: It provides detailed trace reports showing each step the application takes when interfacing with a language model. This helps developers pinpoint where issues might occur in the interaction process.\n\n2. **Performance Analytics**: Langsmith allows developers to analyze performance metrics, helping them understand how efficiently their language model integrations are running and where improvements might be needed.\n\n3. **Debugging Tools**: The toolset comes equipped with debugging tools to assist in identifying and fixing bugs that may arise when applications use language models.\n\n4. **Testing Environments**: Langsmith supports the creation of different scenarios to test how language models perform under various conditions, thus ensuring the robustness and resilience of the model under diverse use cases.\n\n5. **Model Comparison**: Developers can use Langsmith to compare different language models' outputs, aiding in selecting the most suitable model for their specific needs.\n\nOverall, Langsmith is designed to streamline the development process for applications using language models, making it easier to troubleshoot, test, and refine these applications for better performance and reliability." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 269, 'prompt_tokens': 38, 'total_tokens': 307, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_90d33c15d4', 'id': 'chatcmpl-BCul1k0dK1NUgdDLz3ueILm4YGqZw', 'finish_reason': 'stop', 'logprobs': None} id='run-f7c2507a-82dd-4638-8466-c946e8028cc3-0' usage_metadata={'input_tokens': 38, 'output_tokens': 269, 'total_tokens': 307, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
## stroutput Parser

from langchain_core.output_parsers import StrOutputParser
output_parser=StrOutputParser()
chain=prompt|llm|output_parser

response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# Langsmith is a toolkit developed by LangChain that assists developers in building, evaluating, and monitoring applications powered by large language models (LLMs). It aims to address common challenges in creating robust applications by providing features that facilitate testing, debugging, and evaluating the performance of LLM-driven systems.
#
# As part of its offerings, Langsmith includes a platform for tracing and visualizing the execution of language models, logging key details of each interaction, and offering insights into model behavior. This helps developers understand how models are operating within their applications, identify potential issues, and iteratively improve their performance.
#
# Furthermore, Langsmith supports advanced features like implementing and tracking evaluations of language models' outputs, which are crucial for ensuring that these applications perform effectively in real-world scenarios and maintain high standards of accuracy and reliability.
#
# In essence, Langsmith functions as both a development and diagnostic toolset, empowering developers to optimize their use of LLMs by providing the necessary infrastructure to experiment, monitor, and iterate efficiently.
