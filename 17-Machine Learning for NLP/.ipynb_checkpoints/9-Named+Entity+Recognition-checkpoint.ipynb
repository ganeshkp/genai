# %% [markdown]
# ### Named Entity Recognition

# %% [raw]
# sentence="The Eiffel Tower was built from 1887 to 1889 by French engineer Gustave Eiffel, whose company specialized in building metal frameworks and structures."
# """
# Person Eg: Ganesh C Patil
# Place Or Location Eg: India
# Date Eg: September,24-09-1989
# Time  Eg: 4:30pm
# Money Eg: 1 million dollar
# Organization Eg: iNeuron Private Limited
# Percent Eg: 20%, twenty percent
# """

# %%
sentence="The Eiffel Tower was built from 1887 to 1889 by Gustave Eiffel, whose company specialized in building metal frameworks and structures."

# %%
import nltk
import matplotlib.pyplot as plt
words=nltk.word_tokenize(sentence)

# %%
tag_elements=nltk.pos_tag(words)

# %%
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# True

# %%
import nltk
nltk.download('words')
nltk.download('maxent_ne_chunker_tab')
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# True

# %%
nltk.ne_chunk(tag_elements).draw()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 nltk.ne_chunk(tag_elements).draw()
#
# File ~/miniconda3/envs/gen_env/lib/python3.12/site-packages/nltk/tree/tree.py:761, in Tree.draw(self)
#     756 """
#     757 Open a new window containing a graphical diagram of this tree.
#     758 """
#     759 from nltk.draw.tree import draw_trees
# --> 761 draw_trees(self)
#
# File ~/miniconda3/envs/gen_env/lib/python3.12/site-packages/nltk/draw/tree.py:1008, in draw_trees(*trees)
#    1001 def draw_trees(*trees):
#    1002     """
#    1003     Open a new window containing a graphical diagram of the given
#    1004     trees.
#    1005
#    1006     :rtype: None
#    1007     """
# -> 1008     TreeView(*trees).mainloop()
#    1009     return
#
# File ~/miniconda3/envs/gen_env/lib/python3.12/site-packages/nltk/draw/tree.py:859, in TreeView.__init__(self, *trees)
#     855 from math import ceil, sqrt
#     857 self._trees = trees
# --> 859 self._top = Tk()
#     860 self._top.title("NLTK")
#     861 self._top.bind("<Control-x>", self.destroy)
#
# File ~/miniconda3/envs/gen_env/lib/python3.12/tkinter/__init__.py:2346, in Tk.__init__(self, screenName, baseName, className, useTk, sync, use)
#    2344         baseName = baseName + ext
#    2345 interactive = False
# -> 2346 self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2347 if _debug:
#    2348     self.tk.settrace(_print_command)
#
# TclError: couldn't connect to display ":0"
